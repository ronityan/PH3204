# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel(r"D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/data/input.ods",sheet_name="VCE=2V",engine="odf")
data1=pd.read_excel(r"D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/data/input.ods",sheet_name="VCE=3V",engine="odf")

# %%
data
# Out:
#      VBB    VBE   IB   VCC  VCE      IC
# 0   0.01  0.010    0  1.98    2       0
# 1   0.10  0.110    0  1.98    2       0
# 2   0.20  0.210    0  1.98    2       0
# 3   0.30  0.310    0  1.98    2       0
# 4   0.40  0.410    0  1.98    2       0
# 5   0.50  0.510    0  1.98    2      52
# 6   0.60  0.600    7  2.11    2    1094
# 7   0.70  0.650   45  2.03    2  7.2 mA
# 8   0.80  0.664  110  2.07    2    17.7
# 9   0.90  0.680  195  2.19    2    32.8
# 10  1.00  0.692  257  2.25    2    43.8
# 11  1.10  0.701  279  2.49    2    48.1
# 12  1.20    NaN  443  2.88    2    79.5

# %%
plt.grid()
plt.plot(data['VBE'],data['IB'],label='$V_{CE}$=2V',color='red')
plt.plot(data1['VBE'],data1['IB'],label='$V_{CE}$=3V',color='blue')
plt.legend()
plt.xlabel('$V_{BE}(V)$')
plt.ylabel('$I_{B}(\mu A)$')
plt.savefig('D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/plot1.png')
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Ronit Bhuyan\AppData\Local\Temp\ipykernel_1236\1575291046.py:6: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$I_{B}(\mu A)$')

# %%
data2=pd.read_excel(r"D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/data/output.ods",sheet_name="day2_IB=10",engine="odf")
data3=pd.read_excel(r"D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/data/output.ods",sheet_name="iB=20",engine="odf")
data4=pd.read_excel(r"D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/data/output.ods",sheet_name="iB=30",engine="odf")

# %%
data4.iloc[0:24]
#data3.iloc[0:20]
# Out:
#     IB  VCC     VCE    IC
# 0   30  0.1    15.6   105
# 1   30  0.2    20.9   183
# 2   30  0.3    30.0   267
# 3   30  0.4    35.5   385
# 4   30  0.5    43.2   472
# 5   30  0.6    45.5   563
# 6   30  0.7    53.8   638
# 7   30  0.8    55.8   710
# 8   30  0.9    61.6   785
# 9   30  1.0    62.2   856
# 10  30  1.2    70.2  1026
# 11  30  1.5    81.9  1324
# 12  30  1.8    93.6  1503
# 13  30  2.0    98.6  1700
# 14  30  2.2   117.0  2130
# 15  30  2.4   127.9  2270
# 16  30  2.6   140.7  2520
# 17  30  2.8   153.7  2700
# 18  30  3.0   160.4  2830
# 19  30  3.5   190.1  3390
# 20  30  4.0   230.0  3890
# 21  30  5.0   510.0  4540
# 22  30  6.0  1500.0  4580
# 23  30  7.0  2460.0  4750

# %%
plt.figure(figsize=(12,8))
plt.plot(data2['VCE'],data2['IC'],label='$I_{B}$=10$\mu A$',color='red')
plt.plot(data3.iloc[0:20]['VCE'],data3.iloc[0:20]['IC'],label='$I_{B}$=20$\mu A$',color='blue')
plt.plot(data4.iloc[0:23]['VCE'],data4.iloc[0:23]['IC'],label='$I_{B}$=30$\mu A$',color='green')
plt.legend()
plt.xlabel('$V_{CE}(mV)$')
plt.ylabel('$I_{C}(\mu A)$')
#plt.xlim(0,2700)
plt.grid()
plt.savefig('D:/ronit/IISER-K/6 SEM/PH3204/Reports/exp02/plot2.png')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# <>:2: SyntaxWarning: invalid escape sequence '\m'
# <>:3: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Ronit Bhuyan\AppData\Local\Temp\ipykernel_1236\1802882661.py:2: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(data2['VCE'],data2['IC'],label='$I_{B}$=10$\mu A$',color='red')
# C:\Users\Ronit Bhuyan\AppData\Local\Temp\ipykernel_1236\1802882661.py:3: SyntaxWarning: invalid escape sequence '\m'
#   plt.plot(data3.iloc[0:20]['VCE'],data3.iloc[0:20]['IC'],label='$I_{B}$=20$\mu A$',color='blue')
# C:\Users\Ronit Bhuyan\AppData\Local\Temp\ipykernel_1236\1802882661.py:4: SyntaxWarning: invalid escape sequence '\m'
# ...
